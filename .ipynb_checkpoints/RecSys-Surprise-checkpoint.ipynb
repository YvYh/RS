# %% [markdown]
# # Database interactions

# %%
from sqlalchemy import create_engine
from sqlalchemy.exc import ResourceClosedError
from sqlalchemy.types import VARCHAR
from functools import partial

def DatabaseConnect(username, password, host, schema):
    conn_str = "mysql+pymysql://{username}:{password}@{host}/{schema}?charset=utf8&use_unicode=1"\
                             .format(username=username, password=password,schema=schema)
    engine = create_engine(conn_str, pool_recycle=1800)
    return engine

RecSysConnect = partial(DatabaseConnect, 'recsys', 'RecommenderSystems2017', 'localhost', 'recsys')
e = RecSysConnect()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-7cd9e3cd5904> in <module>()
#      10
#      11 RecSysConnect = partial(DatabaseConnect, 'recsys', 'RecommenderSystems2017', 'localhost', 'recsys')
# ---> 12 e = RecSysConnect()
#
# <ipython-input-1-7cd9e3cd5904> in DatabaseConnect(username, password, host, schema)
#       5
#       6 def DatabaseConnect(username, password, host, schema):
# ----> 7     conn_str = "mysql+pymysql://{username}:{password}@{host}/{schema}?charset=utf8&use_unicode=1"                             .format(username=username, password=password,schema=schema)
#       8     engine = create_engine(conn_str, pool_recycle=1800)
#       9     return engine
#
# KeyError: 'host'

# %%
import numpy as np
import pandas as pd
import scipy as sc

# %%
# df = pd.read_excel("c:/recsys/materials/alice.xlsx", index_col='Name').astype(float)
ex ={'Item1': {'Alice': 5.0,    'User1': 3.0, 'User2': 4.0, 'User3': 3.0, 'User4': 1.0},
     'Item2': {'Alice': 3.0,    'User1': 1.0, 'User2': 3.0, 'User3': 3.0, 'User4': 5.0},
     'Item3': {'Alice': 4.0,    'User1': 2.0, 'User2': 4.0, 'User3': 1.0, 'User4': 5.0},
     'Item4': {'Alice': 4.0,    'User1': 3.0, 'User2': 3.0, 'User3': 5.0, 'User4': 2.0},
     'Item5': {'Alice': np.nan, 'User1': 3.0, 'User2': 5.0, 'User3': 4.0, 'User4': 1.0},
}
alice = pd.DataFrame(ex)
ualice = alice.unstack(0).dropna().reset_index()
ualice.columns = ["itemId", "userId", "rating"]
ualice = ualice[["userId", "itemId", "rating"]]

# %% [markdown]
# # Surprise (scikit)
# - Introductory [tutorial](https://medium.com/@m_n_malaeb/the-easy-guide-for-building-python-collaborative-filtering-recommendation-system-in-2017-d2736d2e92a8)
# - Official [documentation](http://surprise.readthedocs.io/en/latest/index.html)
# - Basic explanation of [collaborative filtering](https://medium.com/@cfpinela/recommender-systems-user-based-and-item-based-collaborative-filtering-5d5f375a127f)

# %%
from surprise import SVD, SVDpp, NMF, KNNBasic, KNNWithMeans, KNNWithZScore, SlopeOne
from surprise import Dataset, Reader
from surprise import evaluate, print_perf

# %%
sim_item = {'name': 'cosine',
               'user_based': False  # compute  similarities between items
           }
sim_user = {'name': 'pearson',
               'user_based': True  # compute  similarities between items
           }

algos = [ KNNBasic(2, sim_options=sim_user),     KNNBasic(2, sim_options=sim_item), 
          KNNWithMeans(2, sim_options=sim_user), KNNWithMeans(2, sim_options=sim_item), 
          SlopeOne(), SVD(2), SVDpp(2), NMF(2)]

# %%
# A reader is still needed but only the rating_scale param is requiered.
reader = Reader(rating_scale=(1, 5))
# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(ualice, reader)
#data.df

# %%
trainset = data.build_full_trainset()
for algo in algos:
    algo.train(trainset)
    #print(algo.predict("Alice", "Item5"))
    for i in range(1, 5+1):
        print(i, algo.predict("Alice", "Item%d"%i, alice.loc["Alice","Item%d"%i]))
    print("-----")
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 4.08   {'actual_k': 2, 'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 2.08   {'actual_k': 2, 'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.08   {'actual_k': 2, 'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 3.54   {'actual_k': 2, 'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 3.91   {'actual_k': 2, 'was_impossible': False}
# -----
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 4.51   {'actual_k': 2, 'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 3.49   {'actual_k': 2, 'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.51   {'actual_k': 2, 'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 4.49   {'actual_k': 2, 'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 4.51   {'actual_k': 2, 'was_impossible': False}
# -----
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 4.82   {'actual_k': 2, 'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 2.82   {'actual_k': 2, 'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.82   {'actual_k': 2, 'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 4.28   {'actual_k': 2, 'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 4.87   {'actual_k': 2, 'was_impossible': False}
# -----
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 4.42   {'actual_k': 2, 'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 3.39   {'actual_k': 2, 'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.61   {'actual_k': 2, 'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 4.58   {'actual_k': 2, 'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 4.47   {'actual_k': 2, 'was_impossible': False}
# -----
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 4.00   {'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 3.80   {'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 4.00   {'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 4.20   {'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 4.25   {'was_impossible': False}
# -----
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 3.49   {'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 3.39   {'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.48   {'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 3.55   {'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 3.49   {'was_impossible': False}
# -----
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 3.54   {'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 3.44   {'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.54   {'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 3.64   {'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 3.58   {'was_impossible': False}
# -----
# 1 user: Alice      item: Item1      r_ui = 5.00   est = 3.63   {'was_impossible': False}
# 2 user: Alice      item: Item2      r_ui = 3.00   est = 3.09   {'was_impossible': False}
# 3 user: Alice      item: Item3      r_ui = 4.00   est = 3.22   {'was_impossible': False}
# 4 user: Alice      item: Item4      r_ui = 4.00   est = 3.71   {'was_impossible': False}
# 5 user: Alice      item: Item5      r_ui = nan   est = 4.02   {'was_impossible': False}
# -----

# %% [markdown]
# # MovieLens

# %%
# Load the movielens-100k dataset (download it if needed),
# and split it into 3 folds for cross-validation.
data = Dataset.load_builtin('ml-100k')
data.split(n_folds=3)

# We'll use the famous SVD algorithm.
algo = SVD()

# Evaluate performances of our algorithm on the dataset.
perf = evaluate(algo, data, measures=['RMSE', 'MAE'])

print_perf(perf)
# Out:
# Evaluating RMSE, MAE of algorithm SVD.
#
# ------------
# Fold 1
# RMSE: 0.9469
# MAE:  0.7482
# ------------
# Fold 2
# RMSE: 0.9370
# MAE:  0.7407
# ------------
# Fold 3
# RMSE: 0.9498
# MAE:  0.7481
# ------------
# ------------
# Mean RMSE: 0.9445
# Mean MAE : 0.7457
# ------------
# ------------
#         Fold 1  Fold 2  Fold 3  Mean
# RMSE    0.9469  0.9370  0.9498  0.9445
# MAE     0.7482  0.7407  0.7481  0.7457

# %%
data.raw_ratings
# Out:
# [('305', '184', 3.0, '886323937'),
#  ('705', '28', 4.0, '883427640'),
#  ('249', '478', 4.0, '879572911'),
#  ('880', '546', 3.0, '880167410'),
#  ('619', '809', 1.0, '885954238'),
#  ('255', '834', 4.0, '883216358'),
#  ('206', '361', 1.0, '888180082'),
#  ('524', '191', 4.0, '884634707'),
#  ('758', '890', 3.0, '880672552'),
#  ('819', '302', 5.0, '884012512'),
#  ('903', '276', 5.0, '891380461'),
#  ('666', '134', 5.0, '880567695'),
#  ('269', '96', 1.0, '891450755'),
#  ('472', '685', 3.0, '875978740'),
#  ('938', '151', 4.0, '891356679'),
#  ('64', '8', 4.0, '889737968'),
#  ('343', '257', 3.0, '876402941'),
#  ('194', '81', 2.0, '879523576'),
#  ('295', '79', 4.0, '879517600'),
#  ('593', '155', 5.0, '875671579'),
#  ('76', '324', 4.0, '875027206'),
#  ('776', '769', 3.0, '892920446'),
#  ('246', '284', 1.0, '884922475'),
#  ('401', '64', 3.0, '891032757'),
#  ('897', '195', 5.0, '879991137'),
#  ('821', '427', 5.0, '874793649'),
#  ('916', '650', 4.0, '880844711'),
#  ('222', '2', 3.0, '878183837'),
#  ('82', '222', 3.0, '876311365'),
#  ('837', '294', 4.0, '875721502'),
#  ('874', '276', 4.0, '888632484'),
#  ('661', '164', 4.0, '876035968'),
#  ('435', '42', 3.0, '884131267'),
#  ('234', '1185', 3.0, '892335951'),
#  ('622', '501', 3.0, '882670480'),
#  ('82', '100', 5.0, '876311299'),
#  ('181', '303', 1.0, '878961749'),
#  ('387', '46', 3.0, '886484011'),
#  ('14', '202', 3.0, '890881521'),
#  ('7', '575', 3.0, '892133271'),
#  ('59', '30', 5.0, '888205787'),
#  ('896', '550', 2.0, '887160880'),
#  ('576', '763', 3.0, '886985695'),
#  ('274', '50', 5.0, '878944679'),
#  ('130', '17', 5.0, '875217096'),
#  ('198', '652', 3.0, '884209569'),
#  ('10', '269', 4.0, '877886162'),
#  ('540', '15', 3.0, '882157084'),
#  ('1', '146', 4.0, '875071561'),
#  ('655', '1506', 3.0, '887428871'),
#  ('666', '143', 2.0, '880568064'),
#  ('145', '1002', 1.0, '888398400'),
#  ('325', '548', 3.0, '891480086'),
#  ('393', '169', 3.0, '887745912'),
#  ('234', '1121', 5.0, '892334481'),
#  ('497', '423', 3.0, '879363586'),
#  ('203', '248', 5.0, '880434496'),
#  ('451', '995', 1.0, '879012721'),
#  ('754', '619', 4.0, '879451517'),
#  ('588', '234', 5.0, '890024161'),
#  ('603', '474', 4.0, '891956803'),
#  ('567', '650', 4.0, '882426762'),
#  ('922', '181', 5.0, '891449122'),
#  ('37', '226', 5.0, '880916010'),
#  ('881', '441', 2.0, '876539549'),
#  ('536', '209', 2.0, '882360030'),
#  ('889', '431', 4.0, '880179725'),
#  ('450', '601', 3.0, '882376658'),
#  ('411', '527', 4.0, '892845926'),
#  ('804', '826', 3.0, '879443776'),
#  ('312', '537', 5.0, '891698516'),
#  ('334', '1016', 3.0, '891545185'),
#  ('645', '216', 4.0, '892054732'),
#  ('389', '517', 4.0, '880087977'),
#  ('13', '602', 4.0, '884538634'),
#  ('92', '432', 3.0, '876175031'),
#  ('295', '47', 5.0, '879518166'),
#  ('753', '304', 4.0, '891399686'),
#  ('59', '581', 5.0, '888206015'),
#  ('7', '126', 3.0, '891353254'),
#  ('207', '875', 2.0, '875718889'),
#  ('320', '288', 4.0, '884748277'),
#  ('109', '931', 2.0, '880572407'),
#  ('285', '237', 4.0, '890595636'),
#  ('449', '544', 3.0, '879959023'),
#  ('483', '121', 2.0, '878952692'),
#  ('722', '121', 5.0, '891281182'),
#  ('136', '303', 4.0, '882693234'),
#  ('537', '215', 3.0, '886031342'),
#  ('145', '354', 4.0, '891509877'),
#  ('94', '111', 4.0, '891721414'),
#  ('524', '423', 4.0, '884635358'),
#  ('23', '133', 4.0, '874786220'),
#  ('943', '1044', 3.0, '888639903'),
#  ('468', '12', 4.0, '875291902'),
#  ('454', '490', 2.0, '888266754'),
#  ('881', '576', 3.0, '876538824'),
#  ('385', '727', 1.0, '879443102'),
#  ('387', '458', 1.0, '886481183'),
#  ('38', '22', 5.0, '892429347'),
#  ('161', '118', 2.0, '891172421'),
#  ('883', '153', 5.0, '891723290'),
#  ('851', '1245', 4.0, '875730826'),
#  ('748', '271', 3.0, '879454302'),
#  ('279', '242', 3.0, '877756647'),
#  ('474', '496', 4.0, '887923708'),
#  ('204', '258', 2.0, '892388976'),
#  ('497', '625', 3.0, '879310021'),
#  ('480', '298', 2.0, '891207665'),
#  ('631', '323', 2.0, '888465216'),
#  ('92', '926', 3.0, '875640542'),
#  ('588', '402', 5.0, '890026882'),
#  ('516', '523', 3.0, '891290649'),
#  ('889', '12', 5.0, '880177880'),
#  ('303', '82', 4.0, '879467465'),
#  ('363', '760', 1.0, '891499993'),
#  ('506', '686', 3.0, '889874717'),
#  ('158', '286', 4.0, '880134261'),
#  ('526', '260', 1.0, '885681982'),
#  ('705', '932', 5.0, '883427339'),
#  ('828', '271', 2.0, '891035438'),
#  ('533', '245', 3.0, '890659336'),
#  ('853', '301', 1.0, '879364744'),
#  ('303', '778', 4.0, '879467815'),
#  ('655', '462', 3.0, '888474960'),
#  ('354', '202', 3.0, '891307157'),
#  ('938', '597', 3.0, '891356679'),
#  ('397', '288', 4.0, '882839517'),
#  ('133', '300', 3.0, '890588577'),
#  ('669', '1', 5.0, '892549412'),
#  ('755', '881', 1.0, '882569732'),
#  ('221', '1250', 2.0, '875247855'),
#  ('708', '740', 5.0, '877325687'),
#  ('262', '204', 3.0, '879793667'),
#  ('263', '79', 4.0, '891298047'),
#  ('268', '1090', 2.0, '875745536'),
#  ('807', '385', 4.0, '892530349'),
#  ('363', '2', 4.0, '891495809'),
#  ('151', '659', 5.0, '879524974'),
#  ('535', '61', 3.0, '879619107'),
#  ('661', '443', 4.0, '876035933'),
#  ('394', '172', 4.0, '880886919'),
#  ('933', '583', 3.0, '874854217'),
#  ('308', '175', 5.0, '887736999'),
#  ('730', '328', 2.0, '880310201'),
#  ('40', '340', 2.0, '889041454'),
#  ('125', '300', 5.0, '892835836'),
#  ('707', '381', 3.0, '886286457'),
#  ('641', '483', 5.0, '879370259'),
#  ('642', '779', 3.0, '885843177'),
#  ('644', '291', 4.0, '889076949'),
#  ('60', '501', 3.0, '883327472'),
#  ('432', '248', 4.0, '889416352'),
#  ('417', '158', 2.0, '879649389'),
#  ('303', '551', 2.0, '879544021'),
#  ('533', '100', 5.0, '882902988'),
#  ('639', '153', 3.0, '891240752'),
#  ('92', '1047', 1.0, '875644796'),
#  ('592', '895', 3.0, '882607528'),
#  ('922', '739', 3.0, '891448516'),
#  ('694', '228', 4.0, '875727306'),
#  ('429', '412', 4.0, '882387411'),
#  ('406', '596', 3.0, '879540078'),
#  ('899', '282', 5.0, '884120007'),
#  ('850', '79', 5.0, '883195192'),
#  ('621', '541', 4.0, '874964605'),
#  ('610', '419', 5.0, '888703241'),
#  ('91', '483', 4.0, '891439208'),
#  ('707', '770', 3.0, '886287405'),
#  ('387', '273', 4.0, '886481151'),
#  ('588', '231', 4.0, '890028987'),
#  ('854', '1677', 3.0, '882814368'),
#  ('467', '1011', 2.0, '879532630'),
#  ('479', '498', 5.0, '879461179'),
#  ('254', '35', 2.0, '886475755'),
#  ('870', '841', 2.0, '878737915'),
#  ('796', '219', 4.0, '893218453'),
#  ('200', '405', 3.0, '884127370'),
#  ('496', '268', 4.0, '876063784'),
#  ('405', '196', 1.0, '885546112'),
#  ('899', '31', 3.0, '884121513'),
#  ('889', '92', 3.0, '880177970'),
#  ('336', '72', 3.0, '877756127'),
#  ('694', '630', 3.0, '875728912'),
#  ('13', '419', 3.0, '882398814'),
#  ('606', '709', 5.0, '880927417'),
#  ('85', '630', 3.0, '879453623'),
#  ('325', '272', 3.0, '891477537'),
#  ('921', '313', 5.0, '884673044'),
#  ('622', '739', 2.0, '882671554'),
#  ('199', '473', 4.0, '883783005'),
#  ('860', '245', 3.0, '880829225'),
#  ('256', '25', 5.0, '882150552'),
#  ('747', '234', 5.0, '888640099'),
#  ('409', '609', 3.0, '881108829'),
#  ('222', '228', 5.0, '878181869'),
#  ('940', '151', 3.0, '885921800'),
#  ('943', '200', 4.0, '888639388'),
#  ('823', '240', 3.0, '878438119'),
#  ('405', '186', 5.0, '885547176'),
#  ('878', '216', 4.0, '880869135'),
#  ('442', '405', 3.0, '883390497'),
#  ('94', '1089', 2.0, '891724829'),
#  ('484', '399', 4.0, '891195565'),
#  ('293', '502', 3.0, '888906428'),
#  ('798', '568', 4.0, '875656111'),
#  ('246', '790', 3.0, '884923405'),
#  ('703', '147', 3.0, '875243049'),
#  ('829', '284', 3.0, '891990799'),
#  ('145', '756', 2.0, '885557506'),
#  ('876', '22', 4.0, '879428451'),
#  ('727', '56', 3.0, '883711150'),
#  ('87', '802', 4.0, '879875940'),
#  ('815', '250', 1.0, '878691779'),
#  ('606', '175', 4.0, '880927127'),
#  ('240', '895', 5.0, '885775711'),
#  ('236', '478', 3.0, '890118106'),
#  ('885', '274', 5.0, '885712996'),
#  ('597', '298', 5.0, '875339723'),
#  ('673', '750', 5.0, '888786969'),
#  ('848', '517', 5.0, '887043514'),
#  ('201', '1039', 3.0, '884111599'),
#  ('553', '506', 4.0, '879948655'),
#  ('883', '1592', 5.0, '891692168'),
#  ('119', '407', 3.0, '887038665'),
#  ('84', '225', 4.0, '883452307'),
#  ('295', '504', 4.0, '879517299'),
#  ('174', '742', 4.0, '886434087'),
#  ('127', '750', 1.0, '884363851'),
#  ('634', '282', 4.0, '875729749'),
#  ('29', '480', 4.0, '882821989'),
#  ('455', '1086', 3.0, '879109692'),
#  ('305', '129', 3.0, '886323006'),
#  ('522', '523', 5.0, '876961133'),
#  ('804', '425', 4.0, '879442643'),
#  ('21', '261', 1.0, '874951006'),
#  ('645', '1018', 3.0, '892053518'),
#  ('10', '64', 4.0, '877886598'),
#  ('293', '678', 2.0, '888904439'),
#  ('458', '76', 4.0, '886398121'),
#  ('276', '145', 3.0, '874792692'),
#  ('682', '772', 4.0, '888517922'),
#  ('897', '66', 3.0, '879990973'),
#  ('294', '291', 2.0, '889242469'),
#  ('655', '382', 3.0, '887427131'),
#  ('391', '127', 5.0, '877399236'),
#  ('420', '408', 4.0, '891356927'),
#  ('437', '969', 4.0, '881001888'),
#  ('774', '94', 2.0, '888556248'),
#  ('417', '642', 5.0, '879647947'),
#  ('650', '272', 4.0, '891381546'),
#  ('491', '116', 5.0, '891185209'),
#  ('704', '100', 4.0, '891397491'),
#  ('303', '319', 5.0, '879466065'),
#  ('838', '487', 4.0, '887067126'),
#  ('468', '1070', 5.0, '875301653'),
#  ('378', '252', 4.0, '880045288'),
#  ('11', '211', 3.0, '891905003'),
#  ('655', '378', 1.0, '887430410'),
#  ('197', '187', 5.0, '891409798'),
#  ('374', '5', 4.0, '880937875'),
#  ('366', '234', 1.0, '888857750'),
#  ('424', '1084', 5.0, '880859591'),
#  ('109', '227', 5.0, '880579417'),
#  ('907', '312', 5.0, '885860416'),
#  ('181', '1351', 1.0, '878962168'),
#  ('870', '433', 3.0, '879901879'),
#  ('901', '161', 5.0, '877131147'),
#  ('676', '193', 5.0, '892686606'),
#  ('746', '135', 1.0, '885075655'),
#  ('125', '87', 5.0, '892836464'),
#  ('746', '64', 4.0, '885075790'),
#  ('22', '127', 5.0, '878887869'),
#  ('67', '123', 4.0, '875379322'),
#  ('735', '325', 1.0, '876698022'),
#  ('405', '227', 1.0, '885548049'),
#  ('393', '1258', 3.0, '887744688'),
#  ('524', '203', 4.0, '884634819'),
#  ('590', '864', 1.0, '879439567'),
#  ('505', '71', 4.0, '889333937'),
#  ('381', '512', 4.0, '892696045'),
#  ('537', '673', 3.0, '886031505'),
#  ('442', '17', 4.0, '883388535'),
#  ('458', '25', 1.0, '886394576'),
#  ('393', '1035', 3.0, '889731329'),
#  ('295', '739', 4.0, '879518319'),
#  ('506', '12', 5.0, '874873247'),
#  ('595', '1142', 5.0, '886921199'),
#  ('621', '410', 4.0, '880738623'),
#  ('534', '300', 4.0, '877807486'),
#  ('42', '44', 3.0, '881108548'),
#  ('6', '534', 4.0, '883599354'),
#  ('922', '747', 3.0, '891448247'),
#  ('141', '100', 4.0, '884584688'),
#  ('902', '879', 4.0, '879463485'),
#  ('18', '487', 4.0, '880129454'),
#  ('49', '455', 1.0, '888068791'),
#  ('234', '200', 5.0, '892335074'),
#  ('360', '187', 4.0, '880355527'),
#  ('671', '925', 3.0, '883949781'),
#  ('548', '925', 2.0, '891415709'),
#  ('561', '393', 2.0, '885810309'),
#  ('447', '98', 4.0, '878855873'),
#  ('405', '1225', 1.0, '885547176'),
#  ('305', '638', 5.0, '886324128'),
#  ('854', '100', 5.0, '882812225'),
#  ('588', '404', 3.0, '890026656'),
#  ('640', '68', 4.0, '874778479'),
#  ('268', '810', 2.0, '875744388'),
#  ('913', '79', 4.0, '880758974'),
#  ('883', '172', 4.0, '891696824'),
#  ('301', '604', 4.0, '882075994'),
#  ('455', '214', 3.0, '879112122'),
#  ('92', '1033', 2.0, '890251592'),
#  ('840', '496', 5.0, '891204089'),
#  ('642', '231', 3.0, '886454812'),
#  ('655', '256', 3.0, '887651060'),
#  ('216', '238', 5.0, '880244446'),
#  ('618', '392', 3.0, '891308979'),
#  ('682', '41', 3.0, '888522073'),
#  ('774', '199', 4.0, '888556517'),
#  ('499', '100', 4.0, '885599040'),
#  ('497', '11', 3.0, '879310825'),
#  ('213', '715', 5.0, '878955915'),
#  ('66', '24', 3.0, '883601582'),
#  ('770', '302', 2.0, '875971568'),
#  ('873', '258', 3.0, '891392818'),
#  ('600', '554', 4.0, '888451977'),
#  ('682', '940', 2.0, '888521907'),
#  ('136', '275', 4.0, '882693723'),
#  ('460', '1067', 4.0, '882912316'),
#  ('763', '59', 5.0, '878915765'),
#  ('290', '243', 3.0, '880473474'),
#  ('896', '525', 5.0, '887158164'),
#  ('807', '1089', 4.0, '893084724'),
#  ('160', '544', 4.0, '876768106'),
#  ('112', '332', 4.0, '886398611'),
#  ('181', '146', 1.0, '878962955'),
#  ('933', '317', 4.0, '874853779'),
#  ('293', '724', 3.0, '888907061'),
#  ('130', '932', 3.0, '876251389'),
#  ('936', '16', 4.0, '886832596'),
#  ('363', '25', 3.0, '891496337'),
#  ('57', '932', 3.0, '883697585'),
#  ('608', '865', 4.0, '880403537'),
#  ('890', '603', 5.0, '882404851'),
#  ('169', '525', 3.0, '891359250'),
#  ('826', '38', 3.0, '885690750'),
#  ('92', '174', 5.0, '875654189'),
#  ('782', '1394', 4.0, '891498323'),
#  ('7', '25', 3.0, '891352451'),
#  ('416', '105', 2.0, '876698430'),
#  ('387', '228', 5.0, '886484336'),
#  ('262', '596', 4.0, '879961980'),
#  ('128', '136', 5.0, '879967080'),
#  ('536', '561', 3.0, '882364065'),
#  ('224', '318', 5.0, '888082584'),
#  ('230', '202', 4.0, '880485352'),
#  ('171', '346', 4.0, '891034835'),
#  ('327', '507', 4.0, '887744205'),
#  ('566', '49', 2.0, '881651561'),
#  ('592', '345', 4.0, '888553233'),
#  ('314', '412', 3.0, '877892052'),
#  ('486', '872', 5.0, '879874153'),
#  ('262', '293', 2.0, '879790906'),
#  ('740', '294', 4.0, '879523187'),
#  ('592', '893', 1.0, '882955292'),
#  ('201', '99', 3.0, '884141438'),
#  ('385', '81', 3.0, '879442028'),
#  ('90', '684', 3.0, '891385335'),
#  ('94', '736', 5.0, '891721077'),
#  ('70', '298', 5.0, '884064134'),
#  ('883', '70', 3.0, '891693169'),
#  ('324', '742', 5.0, '880575493'),
#  ('931', '126', 4.0, '891036463'),
#  ('592', '15', 5.0, '882608457'),
#  ('766', '559', 4.0, '891310824'),
#  ('405', '515', 1.0, '885546025'),
#  ('334', '287', 3.0, '891545162'),
#  ('90', '837', 5.0, '891384476'),
#  ('821', '476', 4.0, '874792403'),
#  ('587', '323', 4.0, '892871284'),
#  ('109', '55', 2.0, '880572756'),
#  ('268', '268', 5.0, '876513491'),
#  ('1', '29', 1.0, '878542869'),
#  ('919', '815', 2.0, '875289533'),
#  ('932', '89', 5.0, '891249586'),
#  ('551', '70', 4.0, '892783057'),
#  ('705', '58', 2.0, '883518834'),
#  ('318', '66', 4.0, '884495921'),
#  ('828', '702', 2.0, '891037466'),
#  ('896', '497', 3.0, '887158332'),
#  ('716', '489', 4.0, '879795496'),
#  ('774', '250', 3.0, '888559123'),
#  ('653', '228', 4.0, '878854190'),
#  ('398', '228', 5.0, '875657926'),
#  ('167', '568', 3.0, '892738341'),
#  ('43', '122', 2.0, '884029709'),
#  ('321', '116', 3.0, '879439595'),
#  ('800', '457', 2.0, '887646168'),
#  ('251', '596', 3.0, '886272118'),
#  ('830', '385', 4.0, '891561805'),
#  ('317', '322', 3.0, '891446783'),
#  ('378', '281', 3.0, '880044609'),
#  ('409', '9', 4.0, '881107992'),
#  ('290', '228', 4.0, '880473556'),
#  ('479', '230', 4.0, '879461898'),
#  ('894', '26', 4.0, '882404460'),
#  ('90', '1097', 4.0, '891384885'),
#  ('181', '105', 1.0, '878963304'),
#  ('34', '310', 4.0, '888601628'),
#  ('711', '275', 5.0, '876185855'),
#  ('401', '50', 1.0, '891034050'),
#  ('592', '806', 4.0, '882956586'),
#  ('83', '820', 2.0, '881971231'),
#  ('932', '650', 5.0, '891250498'),
#  ('682', '1016', 2.0, '888518747'),
#  ('646', '750', 3.0, '888528902'),
#  ('92', '591', 4.0, '875640294'),
#  ('715', '68', 4.0, '875963486'),
#  ('84', '591', 4.0, '883451664'),
#  ('436', '1119', 4.0, '887769368'),
#  ('701', '100', 5.0, '891447139'),
#  ('522', '205', 4.0, '876961020'),
#  ('425', '252', 2.0, '878739054'),
#  ('437', '755', 3.0, '880143450'),
#  ('860', '715', 4.0, '885991198'),
#  ('810', '342', 5.0, '890083580'),
#  ('515', '332', 3.0, '887658676'),
#  ('880', '124', 5.0, '880166847'),
#  ('503', '172', 5.0, '880383588'),
#  ('782', '1190', 2.0, '891500230'),
#  ('424', '683', 3.0, '880859084'),
#  ('699', '20', 4.0, '879147239'),
#  ('354', '507', 3.0, '891306892'),
#  ('629', '876', 3.0, '880116023'),
#  ('63', '322', 2.0, '875746986'),
#  ('660', '393', 2.0, '891201541'),
#  ('13', '849', 1.0, '882397833'),
#  ('442', '746', 3.0, '883388354'),
#  ('311', '392', 5.0, '884366067'),
#  ('447', '183', 5.0, '878856394'),
#  ('844', '181', 5.0, '877388183'),
#  ('119', '111', 5.0, '886176779'),
#  ('234', '489', 3.0, '892079237'),
#  ('450', '873', 3.0, '882216475'),
#  ('883', '792', 4.0, '891694182'),
#  ('897', '410', 3.0, '879993621'),
#  ('174', '1091', 3.0, '886515591'),
#  ('15', '815', 1.0, '879456108'),
#  ('324', '270', 5.0, '880575045'),
#  ('452', '173', 4.0, '875261350'),
#  ('268', '402', 1.0, '875745231'),
#  ('743', '259', 3.0, '881277656'),
#  ('567', '679', 4.0, '882426055'),
#  ('626', '270', 2.0, '878771355'),
#  ('250', '264', 3.0, '878089182'),
#  ('592', '1023', 1.0, '882608873'),
#  ('453', '826', 1.0, '877553430'),
#  ('533', '687', 2.0, '879193517'),
#  ('741', '66', 3.0, '891018266'),
#  ('117', '258', 4.0, '880126022'),
#  ('796', '1048', 2.0, '893047288'),
#  ('776', '134', 4.0, '892210460'),
#  ('101', '237', 5.0, '877137015'),
#  ('561', '382', 4.0, '885807842'),
#  ('75', '196', 4.0, '884051948'),
#  ('301', '333', 4.0, '882075454'),
#  ('487', '66', 5.0, '883530484'),
#  ('890', '520', 4.0, '882403643'),
#  ('387', '224', 5.0, '886480703'),
#  ('896', '144', 4.0, '887158333'),
#  ('833', '1214', 4.0, '875225193'),
#  ('295', '747', 4.0, '879518590'),
#  ('897', '71', 5.0, '879991566'),
#  ('373', '71', 5.0, '877098891'),
#  ('7', '675', 5.0, '891352947'),
#  ('748', '22', 4.0, '879455126'),
#  ('83', '243', 3.0, '891181725'),
#  ('506', '518', 4.0, '874873198'),
#  ('582', '1014', 4.0, '882962247'),
#  ('559', '322', 4.0, '891034987'),
#  ('282', '327', 5.0, '879949417'),
#  ('896', '1222', 2.0, '887161393'),
#  ('365', '762', 4.0, '891304300'),
#  ('629', '187', 5.0, '880117031'),
#  ('666', '864', 3.0, '880313523'),
#  ('745', '9', 4.0, '880122809'),
#  ('833', '177', 5.0, '875123299'),
#  ('798', '50', 5.0, '875295810'),
#  ('934', '153', 5.0, '891225716'),
#  ('447', '535', 4.0, '878854954'),
#  ('461', '302', 3.0, '885355646'),
#  ('189', '523', 4.0, '893265596'),
#  ('881', '64', 5.0, '876537933'),
#  ('478', '145', 1.0, '889398599'),
#  ('312', '479', 5.0, '891698365'),
#  ('700', '168', 3.0, '884494420'),
#  ('734', '479', 4.0, '891025541'),
#  ('18', '135', 3.0, '880130065'),
#  ('660', '208', 4.0, '891199201'),
#  ('846', '67', 4.0, '883950252'),
#  ('883', '529', 5.0, '891693012'),
#  ('778', '582', 1.0, '891232769'),
#  ('18', '515', 5.0, '880130155'),
#  ('399', '186', 4.0, '882342669'),
#  ('550', '181', 5.0, '883425283'),
#  ('290', '162', 3.0, '880474107'),
#  ('875', '268', 4.0, '876464755'),
#  ('29', '1018', 4.0, '882821989'),
#  ('398', '117', 4.0, '875653091'),
#  ('609', '294', 2.0, '886895346'),
#  ('405', '1053', 5.0, '885545456'),
#  ('671', '720', 3.0, '884036050'),
#  ('807', '69', 5.0, '892528110'),
#  ('916', '194', 4.0, '880843997'),
#  ('889', '771', 2.0, '880182961'),
#  ('521', '732', 3.0, '884478135'),
#  ('385', '290', 3.0, '879440674'),
#  ('762', '274', 4.0, '878719371'),
#  ('586', '939', 4.0, '884064459'),
#  ('500', '216', 4.0, '883873556'),
#  ('274', '237', 4.0, '878945678'),
#  ('478', '763', 5.0, '889388375'),
#  ('102', '219', 2.0, '888803149'),
#  ('64', '162', 3.0, '889739262'),
#  ('514', '631', 4.0, '875463386'),
#  ('871', '181', 3.0, '888193335'),
#  ('663', '315', 4.0, '889491560'),
#  ('929', '172', 4.0, '879640329'),
#  ('548', '181', 4.0, '891043008'),
#  ('294', '472', 3.0, '889242370'),
#  ('526', '283', 3.0, '885682400'),
#  ('279', '63', 3.0, '875313350'),
#  ('98', '322', 3.0, '880498586'),
#  ('798', '143', 5.0, '875639061'),
#  ('212', '127', 2.0, '879303571'),
#  ('401', '144', 5.0, '891033523'),
#  ('305', '792', 4.0, '886323406'),
#  ('444', '286', 2.0, '890246847'),
#  ('297', '73', 2.0, '875239691'),
#  ('101', '284', 4.0, '877136564'),
#  ('380', '151', 4.0, '885478759'),
#  ('339', '404', 4.0, '891035147'),
#  ('221', '508', 4.0, '875244160'),
#  ('213', '97', 5.0, '878956299'),
#  ('601', '1135', 2.0, '876351141'),
#  ('394', '228', 5.0, '881132876'),
#  ('417', '100', 3.0, '879646166'),
#  ('887', '470', 3.0, '881380773'),
#  ('503', '496', 5.0, '880472474'),
#  ('570', '321', 1.0, '881262795'),
#  ('709', '578', 4.0, '879848645'),
#  ('207', '1350', 2.0, '877878772'),
#  ('286', '133', 4.0, '877531730'),
#  ('201', '11', 4.0, '884112201'),
#  ('825', '257', 4.0, '880931887'),
#  ('829', '20', 3.0, '881707829'),
#  ('450', '4', 3.0, '882373865'),
#  ('270', '1210', 5.0, '876956264'),
#  ('263', '498', 5.0, '891298046'),
#  ('303', '109', 4.0, '879467131'),
#  ('453', '427', 3.0, '877554174'),
#  ('783', '876', 4.0, '884326424'),
#  ('82', '199', 4.0, '878769888'),
#  ('854', '405', 4.0, '882812755'),
#  ('593', '58', 4.0, '875671579'),
#  ('642', '796', 4.0, '885605909'),
#  ('87', '578', 3.0, '879875940'),
#  ('618', '64', 4.0, '891306990'),
#  ('897', '649', 3.0, '879992004'),
#  ('790', '68', 3.0, '885157440'),
#  ('721', '1065', 5.0, '877147383'),
#  ('62', '50', 5.0, '879372216'),
#  ('30', '780', 4.0, '875060217'),
#  ('868', '402', 1.0, '877113412'),
#  ('291', '471', 4.0, '874833746'),
#  ('747', '509', 5.0, '888639176'),
#  ('406', '559', 3.0, '879792974'),
#  ('537', '727', 2.0, '886032245'),
#  ('553', '275', 5.0, '879948552'),
#  ('328', '317', 4.0, '885046976'),
#  ('694', '1269', 5.0, '875726793'),
#  ('833', '467', 2.0, '875038626'),
#  ('94', '96', 3.0, '885872942'),
#  ('388', '326', 5.0, '886438122'),
#  ('795', '240', 2.0, '883767338'),
#  ('324', '327', 4.0, '880575002'),
#  ('305', '197', 2.0, '886322758'),
#  ('321', '499', 3.0, '879440393'),
#  ('798', '204', 4.0, '875742878'),
#  ('533', '286', 4.0, '879193088'),
#  ('932', '1', 4.0, '891249932'),
#  ('614', '756', 4.0, '879465398'),
#  ('459', '100', 1.0, '879562859'),
#  ('213', '514', 5.0, '878956130'),
#  ('393', '471', 4.0, '887744549'),
#  ('497', '413', 3.0, '879362292'),
#  ('649', '1283', 2.0, '891440528'),
#  ('640', '496', 4.0, '874777491'),
#  ('7', '581', 5.0, '891353477'),
#  ('795', '410', 2.0, '880559227'),
#  ('497', '645', 3.0, '878759659'),
#  ('627', '177', 5.0, '879531158'),
#  ('425', '429', 4.0, '878737908'),
#  ('130', '346', 4.0, '884623704'),
#  ('815', '427', 5.0, '887978255'),
#  ('564', '281', 3.0, '888730658'),
#  ('184', '855', 4.0, '889909474'),
#  ('496', '842', 2.0, '876068249'),
#  ('331', '175', 4.0, '877196235'),
#  ('681', '270', 1.0, '885409370'),
#  ('468', '469', 4.0, '875296309'),
#  ('639', '137', 3.0, '891239271'),
#  ('676', '948', 1.0, '892685803'),
#  ('478', '143', 5.0, '889396797'),
#  ('407', '972', 3.0, '876340120'),
#  ('1', '101', 2.0, '878542845'),
#  ('588', '721', 5.0, '890023722'),
#  ('6', '526', 3.0, '883602596'),
#  ('321', '428', 4.0, '879441336'),
#  ('650', '288', 3.0, '891369889'),
#  ('11', '51', 4.0, '891906439'),
#  ('450', '660', 4.0, '887660762'),
#  ('727', '810', 2.0, '883712652'),
#  ('119', '718', 5.0, '874774956'),
#  ('489', '682', 4.0, '891366606'),
#  ('276', '66', 3.0, '874791993'),
#  ('185', '197', 5.0, '883524428'),
#  ('797', '243', 2.0, '879439104'),
#  ('393', '977', 4.0, '887745501'),
#  ('345', '462', 5.0, '884901637'),
#  ('158', '271', 4.0, '880132232'),
#  ('326', '230', 3.0, '879876861'),
#  ('632', '568', 3.0, '879458142'),
#  ('221', '461', 4.0, '875245574'),
#  ('409', '474', 5.0, '881107351'),
#  ('378', '183', 4.0, '880331829'),
#  ('894', '923', 5.0, '882404278'),
#  ('361', '150', 2.0, '879440345'),
#  ('291', '729', 4.0, '874871442'),
#  ('345', '272', 5.0, '884900426'),
#  ('715', '1217', 2.0, '875963998'),
#  ('851', '915', 5.0, '893090752'),
#  ('144', '435', 4.0, '888105387'),
#  ('445', '325', 1.0, '891199533'),
#  ('15', '323', 1.0, '879455311'),
#  ('500', '298', 4.0, '890009939'),
#  ('82', '112', 1.0, '877452357'),
#  ('494', '238', 5.0, '879541207'),
#  ('130', '271', 5.0, '879352077'),
#  ('109', '82', 5.0, '880572680'),
#  ('372', '262', 4.0, '876869066'),
#  ('653', '385', 4.0, '878854190'),
#  ('480', '166', 5.0, '891208185'),
#  ('479', '71', 1.0, '879461143'),
#  ('75', '284', 2.0, '884050393'),
#  ('394', '496', 5.0, '880887206'),
#  ('166', '315', 3.0, '886397478'),
#  ('268', '230', 3.0, '875310824'),
#  ('747', '985', 2.0, '888732640'),
#  ('353', '326', 2.0, '891402444'),
#  ('798', '1509', 3.0, '875915155'),
#  ('497', '384', 2.0, '879362985'),
#  ('916', '1073', 4.0, '880844445'),
#  ('643', '420', 4.0, '891449803'),
#  ('655', '1379', 3.0, '888685879'),
#  ('343', '188', 4.0, '876407749'),
#  ('924', '313', 4.0, '886065805'),
#  ('363', '143', 2.0, '891496667'),
#  ('493', '343', 3.0, '884130074'),
#  ('279', '546', 3.0, '875296924'),
#  ('334', '500', 3.0, '891547334'),
#  ('358', '643', 3.0, '891270091'),
#  ('637', '619', 2.0, '882903914'),
#  ('116', '332', 3.0, '876451998'),
#  ('887', '393', 4.0, '881381114'),
#  ('158', '298', 3.0, '880132513'),
#  ('487', '230', 5.0, '884036466'),
#  ('1', '58', 4.0, '878542960'),
#  ('460', '257', 2.0, '882912342'),
#  ('417', '713', 2.0, '879646052'),
#  ('63', '15', 3.0, '875747439'),
#  ('842', '269', 5.0, '891217834'),
#  ('422', '333', 4.0, '875655986'),
#  ('322', '656', 5.0, '887314027'),
#  ('664', '469', 3.0, '876524474'),
#  ('151', '202', 5.0, '879542753'),
#  ('502', '243', 3.0, '883702945'),
#  ('144', '9', 5.0, '888104191'),
#  ('580', '271', 5.0, '884124248'),
#  ('25', '25', 5.0, '885853415'),
#  ('469', '161', 3.0, '879523802'),
#  ('498', '183', 4.0, '881957905'),
#  ('1', '144', 4.0, '875073180'),
#  ('846', '509', 4.0, '883948765'),
#  ('648', '412', 1.0, '884367318'),
#  ('189', '484', 5.0, '893266105'),
#  ('206', '882', 1.0, '888180049'),
#  ('649', '147', 4.0, '891440214'),
#  ('551', '595', 2.0, '892784744'),
#  ('782', '1082', 3.0, '891500230'),
#  ('600', '1274', 2.0, '888453145'),
#  ('18', '378', 3.0, '880131804'),
#  ('936', '1160', 5.0, '886833795'),
#  ('379', '116', 4.0, '880525194'),
#  ('85', '1170', 3.0, '879456350'),
#  ('138', '357', 4.0, '879024327'),
#  ('236', '255', 3.0, '890116747'),
#  ('94', '188', 4.0, '885870665'),
#  ('659', '257', 2.0, '891044849'),
#  ('642', '259', 5.0, '885605095'),
#  ('160', '118', 3.0, '876768828'),
#  ('478', '26', 5.0, '889396212'),
#  ('141', '405', 3.0, '884585105'),
#  ('701', '300', 3.0, '891446520'),
#  ('433', '59', 5.0, '880585730'),
#  ('380', '1168', 3.0, '885479833'),
#  ('268', '561', 3.0, '876513897'),
#  ('868', '581', 2.0, '877109748'),
#  ('416', '431', 4.0, '886316164'),
#  ('341', '1280', 2.0, '890757782'),
#  ('301', '79', 5.0, '882076403'),
#  ('524', '471', 4.0, '884322169'),
#  ('84', '12', 5.0, '883452874'),
#  ('13', '912', 2.0, '892014861'),
#  ('661', '603', 3.0, '876016726'),
#  ('568', '242', 4.0, '877906547'),
#  ('96', '190', 4.0, '884402978'),
#  ('919', '9', 5.0, '875288749'),
#  ('468', '70', 3.0, '875287535'),
#  ('772', '879', 4.0, '877533731'),
#  ('347', '475', 4.0, '881652417'),
#  ('665', '255', 4.0, '884290608'),
#  ('655', '1194', 5.0, '887474605'),
#  ('702', '343', 2.0, '885767629'),
#  ('744', '28', 3.0, '881170416'),
#  ('870', '802', 3.0, '879714763'),
#  ('896', '325', 1.0, '887157732'),
#  ('862', '24', 4.0, '879302990'),
#  ('181', '291', 3.0, '878962997'),
#  ('889', '1553', 3.0, '880180979'),
#  ('577', '409', 5.0, '880470682'),
#  ('840', '479', 4.0, '891204385'),
#  ('109', '386', 1.0, '880579916'),
#  ('94', '17', 2.0, '891721494'),
#  ('346', '153', 3.0, '874948252'),
#  ('345', '535', 3.0, '884994136'),
#  ('417', '431', 4.0, '879647431'),
#  ('497', '217', 4.0, '879362382'),
#  ('572', '286', 4.0, '879449179'),
#  ('846', '792', 4.0, '883948221'),
#  ('131', '287', 4.0, '883681351'),
#  ('461', '158', 2.0, '885355930'),
#  ('429', '739', 3.0, '882387140'),
#  ('538', '199', 5.0, '877364067'),
#  ('868', '1031', 1.0, '877109535'),
#  ('236', '655', 3.0, '890116670'),
#  ('615', '268', 4.0, '879447642'),
#  ('887', '1079', 1.0, '881378773'),
#  ('868', '232', 1.0, '877109082'),
#  ('83', '22', 5.0, '880307724'),
#  ('639', '1020', 4.0, '891240136'),
#  ('254', '678', 3.0, '886470859'),
#  ('174', '845', 5.0, '886433771'),
#  ('795', '234', 4.0, '883251200'),
#  ('889', '1', 3.0, '880177104'),
#  ('416', '311', 3.0, '886314877'),
#  ('23', '421', 5.0, '874786770'),
#  ('33', '329', 4.0, '891964326'),
#  ('425', '895', 4.0, '890346198'),
#  ('620', '82', 5.0, '889988146'),
#  ('748', '748', 4.0, '879454208'),
#  ('432', '50', 5.0, '889416012'),
#  ('506', '66', 4.0, '874874676'),
#  ('663', '328', 4.0, '889491861'),
#  ('555', '87', 4.0, '879975505'),
#  ('159', '595', 5.0, '880486009'),
#  ('59', '382', 4.0, '888205574'),
#  ('181', '678', 2.0, '878961369'),
#  ('588', '880', 1.0, '890014996'),
#  ('295', '164', 5.0, '879518395'),
#  ('782', '1012', 2.0, '891499344'),
#  ('371', '655', 4.0, '880435238'),
#  ('606', '157', 4.0, '880926018'),
#  ('825', '50', 4.0, '880755418'),
#  ('878', '474', 5.0, '880868819'),
#  ('361', '504', 4.0, '879441215'),
#  ('890', '152', 4.0, '882403299'),
#  ('304', '742', 3.0, '884968078'),
#  ('648', '227', 3.0, '884882803'),
#  ('854', '275', 4.0, '882814571'),
#  ('825', '294', 4.0, '880755305'),
#  ('664', '286', 4.0, '876523092'),
#  ('892', '95', 4.0, '886608770'),
#  ('194', '135', 3.0, '879521474'),
#  ('10', '33', 4.0, '877893020'),
#  ('54', '471', 4.0, '880937399'),
#  ('222', '475', 4.0, '877563252'),
#  ('644', '294', 4.0, '889076095'),
#  ('119', '199', 5.0, '874781994'),
#  ('393', '99', 3.0, '889727536'),
#  ('813', '538', 3.0, '883752380'),
#  ('774', '98', 4.0, '888557682'),
#  ('1', '41', 2.0, '876892818'),
#  ('283', '216', 4.0, '879298206'),
#  ('267', '158', 4.0, '878973126'),
#  ('38', '444', 1.0, '892433912'),
#  ('537', '923', 3.0, '886031342'),
#  ('643', '229', 3.0, '891449640'),
#  ('639', '19', 4.0, '891239813'),
#  ('207', '269', 4.0, '877845577'),
#  ('916', '42', 5.0, '880844958'),
#  ('845', '303', 1.0, '885409374'),
#  ('311', '205', 5.0, '884365357'),
#  ('900', '483', 4.0, '877833924'),
#  ('159', '1023', 2.0, '880557741'),
#  ('339', '153', 4.0, '891033932'),
#  ('746', '228', 4.0, '885075243'),
#  ('693', '449', 2.0, '875483407'),
#  ('481', '199', 5.0, '885828543'),
#  ('634', '932', 3.0, '877018004'),
#  ('416', '651', 4.0, '886316439'),
#  ('761', '457', 1.0, '876189950'),
#  ('854', '250', 4.0, '882812376'),
#  ('394', '202', 5.0, '880888245'),
#  ('697', '754', 3.0, '882621431'),
#  ('457', '66', 4.0, '882547694'),
#  ('700', '73', 3.0, '884494380'),
#  ('383', '504', 4.0, '891193108'),
#  ('38', '627', 5.0, '892431586'),
#  ('497', '651', 4.0, '879310762'),
#  ('806', '111', 3.0, '882385237'),
#  ('215', '82', 3.0, '891435995'),
#  ('286', '888', 5.0, '884583549'),
#  ('450', '469', 4.0, '882396153'),
#  ('757', '11', 4.0, '888466583'),
#  ('796', '761', 3.0, '893048622'),
#  ('831', '508', 3.0, '891354947'),
#  ('387', '195', 4.0, '886479528'),
#  ('416', '284', 4.0, '893142144'),
#  ('521', '829', 2.0, '884476168'),
#  ('345', '303', 4.0, '884900448'),
#  ('488', '492', 2.0, '891375784'),
#  ('250', '357', 4.0, '878091915'),
#  ('766', '215', 3.0, '891309250'),
#  ('312', '632', 3.0, '891698764'),
#  ('645', '357', 5.0, '892053274'),
#  ('33', '751', 4.0, '891964188'),
#  ('276', '218', 4.0, '874792663'),
#  ('184', '97', 2.0, '889908539'),
#  ('840', '435', 4.0, '891204114'),
#  ('577', '728', 3.0, '880475226'),
#  ('342', '1315', 1.0, '875318742'),
#  ('825', '274', 4.0, '889020826'),
#  ('32', '408', 3.0, '883717684'),
#  ('840', '1065', 5.0, '891209285'),
#  ('279', '373', 4.0, '875659844'),
#  ('617', '238', 3.0, '883789249'),
#  ('633', '526', 4.0, '877212250'),
#  ('431', '879', 3.0, '877844489'),
#  ('933', '940', 1.0, '874938664'),
#  ('896', '228', 5.0, '887158266'),
#  ('391', '48', 4.0, '877399171'),
#  ('293', '144', 4.0, '888905819'),
#  ('125', '8', 4.0, '879454419'),
#  ('253', '747', 3.0, '891628501'),
#  ('493', '435', 5.0, '884132015'),
#  ('336', '405', 3.0, '877760374'),
#  ('6', '435', 4.0, '883601529'),
#  ('200', '411', 3.0, '876042824'),
#  ('72', '271', 1.0, '880036346'),
#  ('551', '317', 5.0, '892777092'),
#  ('416', '560', 3.0, '886319079'),
#  ('905', '273', 3.0, '884984148'),
#  ('609', '1', 1.0, '886896185'),
#  ('293', '371', 2.0, '888906906'),
#  ('336', '383', 1.0, '877758935'),
#  ('385', '181', 1.0, '879439923'),
#  ('95', '671', 3.0, '880571045'),
#  ('506', '323', 3.0, '875444631'),
#  ('880', '366', 2.0, '880242257'),
#  ('104', '249', 3.0, '888465675'),
#  ('116', '255', 3.0, '876452524'),
#  ('664', '132', 4.0, '878092569'),
#  ('878', '549', 4.0, '880869303'),
#  ('453', '941', 2.0, '877561613'),
#  ('468', '209', 5.0, '875296309'),
#  ('642', '928', 5.0, '886131546'),
#  ('621', '65', 3.0, '885596944'),
#  ('325', '504', 3.0, '891477905'),
#  ('840', '163', 4.0, '891204295'),
#  ('62', '1128', 2.0, '879372831'),
#  ('654', '95', 4.0, '887864204'),
#  ('311', '199', 4.0, '884365485'),
#  ('64', '151', 3.0, '879366214'),
#  ('804', '292', 2.0, '879441099'),
#  ('312', '132', 5.0, '891699121'),
#  ('429', '173', 4.0, '882384494'),
#  ('276', '425', 4.0, '874791101'),
#  ('368', '145', 2.0, '889783586'),
#  ('625', '258', 4.0, '891262561'),
#  ('276', '1035', 3.0, '874793035'),
#  ('738', '408', 5.0, '875349584'),
#  ('458', '844', 4.0, '886394576'),
#  ('632', '98', 4.0, '879457217'),
#  ('923', '288', 5.0, '880386897'),
#  ('343', '703', 4.0, '876404426'),
#  ('753', '347', 2.0, '891401167'),
#  ('82', '211', 4.0, '878769815'),
#  ('392', '285', 3.0, '891039050'),
#  ('301', '90', 3.0, '882078360'),
#  ('262', '385', 2.0, '879795030'),
#  ('653', '492', 4.0, '880149999'),
#  ('472', '395', 3.0, '875982559'),
#  ('837', '763', 1.0, '875722123'),
#  ('897', '228', 4.0, '879991607'),
#  ('535', '179', 4.0, '879617489'),
#  ('189', '503', 3.0, '893266137'),
#  ('452', '1383', 1.0, '886149828'),
#  ('474', '1113', 3.0, '887926059'),
#  ('152', '294', 4.0, '880149098'),
#  ('882', '515', 5.0, '879865307'),
#  ('582', '328', 3.0, '882960555'),
#  ('1', '21', 1.0, '878542772'),
#  ('549', '151', 3.0, '881672300'),
#  ('592', '313', 5.0, '882955258'),
#  ('532', '1199', 3.0, '874789155'),
#  ('267', '218', 4.0, '878972650'),
#  ('405', '1535', 1.0, '885549635'),
#  ('341', '1527', 4.0, '890757717'),
#  ('144', '244', 3.0, '888104588'),
#  ('542', '384', 3.0, '886533227'),
#  ('416', '451', 5.0, '893212623'),
#  ('106', '14', 4.0, '881449486'),
#  ('232', '475', 5.0, '880062469'),
#  ('870', '856', 3.0, '879715002'),
#  ('403', '476', 4.0, '879790468'),
#  ('269', '143', 3.0, '891450385'),
#  ('727', '840', 2.0, '883709884'),
#  ('404', '348', 3.0, '883790400'),
#  ('606', '637', 3.0, '880927750'),
#  ('887', '369', 5.0, '881378896'),
#  ('939', '756', 5.0, '880261532'),
#  ('323', '9', 4.0, '878739325'),
#  ('534', '456', 5.0, '877808300'),
#  ('840', '216', 4.0, '891205123'),
#  ('90', '354', 3.0, '891382240'),
#  ('580', '323', 2.0, '884124383'),
#  ('666', '4', 5.0, '880314477'),
#  ('921', '240', 1.0, '879379621'),
#  ('579', '89', 3.0, '880952102'),
#  ('707', '482', 3.0, '886286032'),
#  ('543', '566', 4.0, '877545605'),
#  ('476', '70', 3.0, '883364680'),
#  ('293', '148', 1.0, '888907015'),
#  ('346', '712', 3.0, '875264985'),
#  ('776', '569', 3.0, '892920403'),
#  ('31', '321', 4.0, '881547746'),
#  ('383', '641', 4.0, '891192778'),
#  ('207', '88', 2.0, '878104627'),
#  ('290', '97', 3.0, '880475016'),
#  ('29', '343', 3.0, '882821673'),
#  ('374', '162', 2.0, '880396511'),
#  ('299', '48', 4.0, '877880612'),
#  ('509', '307', 2.0, '883590729'),
#  ('751', '28', 5.0, '889133064'),
#  ('693', '504', 5.0, '875483302'),
#  ('334', '855', 3.0, '891547513'),
#  ('653', '117', 4.0, '878854810'),
#  ('804', '981', 3.0, '879444077'),
#  ('880', '379', 4.0, '880241434'),
#  ('642', '795', 4.0, '886570173'),
#  ('339', '549', 4.0, '891034040'),
#  ('450', '496', 5.0, '882373532'),
#  ('916', '280', 2.0, '880843864'),
#  ('396', '840', 3.0, '884646648'),
#  ('655', '1407', 2.0, '887491131'),
#  ('899', '597', 2.0, '884120270'),
#  ('796', '155', 5.0, '893047241'),
#  ('934', '121', 3.0, '891189819'),
#  ('869', '294', 3.0, '884490151'),
#  ('276', '449', 2.0, '874792520'),
#  ('374', '48', 5.0, '880395426'),
#  ('500', '125', 3.0, '883865632'),
#  ('82', '496', 4.0, '878769992'),
#  ('264', '558', 5.0, '886122447'),
#  ('642', '356', 4.0, '886132104'),
#  ('622', '277', 4.0, '882590252'),
#  ('303', '333', 4.0, '879466088'),
#  ('890', '135', 5.0, '882405546'),
#  ('770', '246', 5.0, '875971813'),
#  ('654', '596', 3.0, '887863802'),
#  ('200', '25', 4.0, '876042234'),
#  ('363', '218', 2.0, '891497174'),
#  ('267', '172', 5.0, '878974783'),
#  ('95', '172', 4.0, '879196847'),
#  ('295', '102', 4.0, '879518339'),
#  ('541', '1185', 2.0, '883866028'),
#  ('472', '373', 4.0, '875983129'),
#  ...]
